# %% [markdown]
# # 1. Setup

# %% [markdown]
# # 1.1 Install Dependencies

# %%
# !pip install tensorflow==2.4.1

# %% [markdown]
# # 1.2 Import Dependencies

# %%
import cv2
import os
import random
import numpy as np
from matplotlib import pyplot as plt

# %%
#import tensorflow dependencies - Functional API
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf

# %% [markdown]
# # 1.3 Set GPU Growth

# %%
#Avoid OOM errors by setting GPU memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# # 1.4 Create Folder Structures

# %%
POS_PATH = os.path.join('data', 'positive')
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')

# %%
# Make the directories
os.makedirs(POS_PATH)
os.makedirs(NEG_PATH)
os.makedirs(ANC_PATH)

# %% [markdown]
# # 2. Collect Positives and Anchors

# %% [markdown]
# # 2.1 Untar Labelled Faces in the Wild Dataset

# %%
# http://vis-www.cs.umass.edu/lfw/

# %%
# Uncompress Tar GZ Labelled Faces in the Wild Dataset

# !tar -xf lfw.tgz

# %%
# Move LFW Images to the following repository data/negative
for directory in os.listdir('lfw'):
    for file in os.listdir(os.path.join('lfw', directory)):
        EX_PATH = os.path.join('lfw', directory, file)
        NEW_PATH = os.path.join(NEG_PATH, file)
        os.replace(EX_PATH, NEW_PATH)

# %% [markdown]
# # 2.2 Collect Positive and Anchor Classes

# %%
# Import uuid library to generate unique image names
import uuid

# %%
os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))
# Out:
# 'data\\anchor\\9e0bafe8-dbfb-11ec-933b-38fc98e17070.jpg'

# %%
# Establish a connection to the webcam
cap = cv2.VideoCapture(0)
while cap.isOpened(): 
    ret, frame = cap.read()
   
    # Cut down frame to 250x250px
    frame = frame[120:120+250,200:200+250, :]
    
    # Collect anchors 
    if cv2.waitKey(1) & 0XFF == ord('a'):
        # Create the unique file path 
        imgname = os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))
        # Write out anchor image
        cv2.imwrite(imgname, frame)
    
    # Collect positives
    if cv2.waitKey(1) & 0XFF == ord('p'):
        # Create the unique file path q
        imgname = os.path.join(POS_PATH, '{}.jpg'.format(uuid.uuid1()))
        # Write out positive image
        cv2.imwrite(imgname, frame)
    
    # Show image back to screen
    cv2.imshow('Image Collection', frame)
    
    # Breaking gracefully
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break
        
# Release the webcam
cap.release()
# Close the image show frame
cv2.destroyAllWindows()

# %%
plt.imshow(frame)

# %% [markdown]
# # 3. Load and Preprocess Images

# %% [markdown]
# # 3.1 Get Image Directories

# %%
anchor = tf.data.Dataset.list_files(ANC_PATH+'\*.jpg').take(3000)
positive = tf.data.Dataset.list_files(POS_PATH+'\*.jpg').take(3000)
negative = tf.data.Dataset.list_files(NEG_PATH+'\*.jpg').take(3000)

# %%
dir_test = anchor.as_numpy_iterator()

# %%
print(dir_test.next())
# Out:
# b'data\\anchor\\f8b297db-dbfb-11ec-9d77-38fc98e17070.jpg'

# %% [markdown]
# # 3.2 Preprocessing - Scale and Resize

# %%
def preprocess(file_path):
    
    # Read in image from file path
    byte_img = tf.io.read_file(file_path)
    # Load in the image 
    img = tf.io.decode_jpeg(byte_img)
    
    # Preprocessing steps - resizing the image to be 100x100x3
    img = tf.image.resize(img, (100,100))
    # Scale image to be between 0 and 1 
    img = img / 255.0

    # Return image
    return img

# %%
img=preprocess('data\\anchor\\f8b297db-dbfb-11ec-9d77-38fc98e17070.jpg')

# %%
 img.numpy().max()
# Out:
# 1.0

# %%
plt.imshow(img)

# %%
Dataset.map(preprocess)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 Dataset.map(preprocess)
#
# NameError: name 'Dataset' is not defined

# %% [markdown]
# # 3.3 Create Labelled Dataset

# %%
# (anchor, positive) => 1,1,1,1,1
# (anchor, negative) => 0,0,0,0,0

# %%
positives = tf.data.Dataset.zip((anchor, positive, tf.data.Dataset.from_tensor_slices(tf.ones(len(anchor)))))
negatives = tf.data.Dataset.zip((anchor, negative, tf.data.Dataset.from_tensor_slices(tf.zeros(len(anchor)))))
data = positives.concatenate(negatives)

# %%
samples = data.as_numpy_iterator()

# %%
exampple = samples.next()

# %%
exampple
# Out:
# (b'data\\anchor\\f7682aeb-dbfb-11ec-a96a-38fc98e17070.jpg',
#  b'data\\positive\\0f10ed06-dbfc-11ec-b2ac-38fc98e17070.jpg',
#  1.0)

# %% [markdown]
# # 3.4 Build Train and Test Partition

# %%
def preprocess_twin(input_img, validation_img, label):
    return(preprocess(input_img), preprocess(validation_img), label)

# %%
res = preprocess_twin(*exampple)

# %%
plt.imshow(res[1])

# %%
res[2]
# Out:
# 1.0

# %%
# Build dataloader pipeline
data = data.map(preprocess_twin)
data = data.cache()
data = data.shuffle(buffer_size=10000)

# %%
# Training partition
train_data = data.take(round(len(data)*.7))
train_data = train_data.batch(16)
train_data = train_data.prefetch(8)

# %%
# Testing partition
test_data = data.skip(round(len(data)*.7))
test_data = test_data.take(round(len(data)*.3))
test_data = test_data.batch(16)
test_data = test_data.prefetch(8)

# %% [markdown]
# # 4. Model Engineering

# %% [markdown]
# # 4.1 Build Embedding Layer

# %%
inp = Input(shape=(100,100,3), name='input_image')

# %%
c1 = Conv2D(64, (10,10), activation='relu')(inp)

# %%
m1 = MaxPooling2D(64, (2,2), padding='same')(c1)

# %%
c2 = Conv2D(128, (7,7), activation='relu')(m1)
m2 = MaxPooling2D(64, (2,2), padding='same')(c2)

# %%
c3 = Conv2D(128, (4,4), activation='relu')(m2)
m3 = MaxPooling2D(64, (2,2), padding='same')(c3)

# %%
c4 = Conv2D(256, (4,4), activation='relu')(m3)
f1 = Flatten()(c4)
d1 = Dense(4096, activation='sigmoid')(f1)

# %%
mod = Model(inputs=[inp], outputs=[d1], name='embedding')

# %%
mod.summary()
# Out:
# Model: "embedding"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_image (InputLayer)     [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 91, 91, 64)        19264
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 46, 46, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 40, 40, 128)       401536
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 17, 17, 128)       262272
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 256)         524544
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              37752832
# =================================================================
# Total params: 38,960,448
# Trainable params: 38,960,448
# Non-trainable params: 0
# _________________________________________________________________

# %%
def make_embedding(): 
    inp = Input(shape=(100,100,3), name='input_image')
    
    # First block
    c1 = Conv2D(64, (10,10), activation='relu')(inp)
    m1 = MaxPooling2D(64, (2,2), padding='same')(c1)
    
    # Second block
    c2 = Conv2D(128, (7,7), activation='relu')(m1)
    m2 = MaxPooling2D(64, (2,2), padding='same')(c2)
    
    # Third block 
    c3 = Conv2D(128, (4,4), activation='relu')(m2)
    m3 = MaxPooling2D(64, (2,2), padding='same')(c3)
    
    # Final embedding block
    c4 = Conv2D(256, (4,4), activation='relu')(m3)
    f1 = Flatten()(c4)
    d1 = Dense(4096, activation='sigmoid')(f1)
    
    
    return Model(inputs=[inp], outputs=[d1], name='embedding')

# %%
embedding = make_embedding()

# %%
embedding.summary()
# Out:
# Model: "embedding"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_image (InputLayer)     [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 91, 91, 64)        19264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 46, 46, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 40, 40, 128)       401536
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 17, 17, 128)       262272
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 256)         524544
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              37752832
# =================================================================
# Total params: 38,960,448
# Trainable params: 38,960,448
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 4.2 Build Distance Layer

# %%
# Siamese L1 Distance class
class L1Dist(Layer):
    
    # Init method - inheritance
    def __init__(self, **kwargs):
        super().__init__()
       
    # Magic happens here - similarity calculation
    def call(self, input_embedding, validation_embedding):
        return tf.math.abs(input_embedding - validation_embedding)

# %%
l1 = L1Dist()

# %%
l1(anchor_embedding, validation_embedding)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 l1(anchor_embedding, validation_embedding)
#
# NameError: name 'anchor_embedding' is not defined

# %% [markdown]
# # 4.3 Make Siamese Model

# %%
input_image = Input(name='input_img', shape=(100,100,3))
validation_image = Input(name='validation_img', shape=(100,100,3))

# %%
inp_embedding = embedding(input_image)
val_embedding = embedding(validation_image)

# %%
siamese_layer = L1Dist()

# %%
distances = siamese_layer(inp_embedding, val_embedding)

# %%
classifier = Dense(1, activation='sigmoid')(distances)

# %%
classifier
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_2')>

# %%
siamese_network = Model(inputs=[input_image, validation_image], outputs=classifier, name='SiameseNetwork')

# %%
siamese_network.summary()
# Out:
# Model: "SiameseNetwork"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_img (InputLayer)          [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# validation_img (InputLayer)     [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# embedding (Functional)          (None, 4096)         38960448    input_img[0][0]
#                                                                  validation_img[0][0]
# __________________________________________________________________________________________________
# l1_dist_1 (L1Dist)              (None, 4096)         0           embedding[0][0]
#                                                                  embedding[1][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            4097        l1_dist_1[0][0]
# ==================================================================================================
# Total params: 38,964,545
# Trainable params: 38,964,545
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def make_siamese_model(): 
    
    # Anchor image input in the network
    input_image = Input(name='input_img', shape=(100,100,3))
    
    # Validation image in the network 
    validation_image = Input(name='validation_img', shape=(100,100,3))
    
    # Combine siamese distance components
    siamese_layer = L1Dist()
    siamese_layer._name = 'distance'
    distances = siamese_layer(embedding(input_image), embedding(validation_image))
    
    # Classification layer 
    classifier = Dense(1, activation='sigmoid')(distances)
    
    return Model(inputs=[input_image, validation_image], outputs=classifier, name='SiameseNetwork')

# %%
siamese_model = make_siamese_model()

# %%
siamese_model.summary()
# Out:
# Model: "SiameseNetwork"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_img (InputLayer)          [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# validation_img (InputLayer)     [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# embedding (Functional)          (None, 4096)         38960448    input_img[0][0]
#                                                                  validation_img[0][0]
# __________________________________________________________________________________________________
# distance (L1Dist)               (None, 4096)         0           embedding[2][0]
#                                                                  embedding[3][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            4097        distance[0][0]
# ==================================================================================================
# Total params: 38,964,545
# Trainable params: 38,964,545
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 5. Training

# %% [markdown]
# # 5.1 Setup Loss and Optimizer

# %%
binary_cross_loss = tf.losses.BinaryCrossentropy()

# %%
opt = tf.keras.optimizers.Adam(1e-4) # 0.0001

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, 'ckpt')
checkpoint = tf.train.Checkpoint(opt=opt, siamese_model=siamese_model)

# %% [markdown]
# # 5.3 Build Train Step Function

# %%
test_batch = train_data.as_numpy_iterator()

# %%
batch_1 = test_batch.next()

# %%
X = batch_1[:2]

# %%
y = batch_1[2]

# %%
y
# Out:
# array([1., 0., 1., 0., 0., 0., 1., 1., 0., 1., 0., 0., 0., 1., 1., 1.],
#       dtype=float32)

# %%
tf.losses.BinaryCrossentropy??

# %%
@tf.function
def train_step(batch):
    
    # Record all of our operations 
    with tf.GradientTape() as tape:     
        # Get anchor and positive/negative image
        X = batch[:2]
        # Get label
        y = batch[2]
        
        # Forward pass
        yhat = siamese_model(X, training=True)
        # Calculate loss
        loss = binary_cross_loss(y, yhat)
    print(loss)
        
    # Calculate gradients
    grad = tape.gradient(loss, siamese_model.trainable_variables)
    
    # Calculate updated weights and apply to siamese model
    opt.apply_gradients(zip(grad, siamese_model.trainable_variables))
        
    # Return loss
    return loss

# %% [markdown]
# # 5.4 Build Training Loop

# %%
# Import metric calculations
from tensorflow.keras.metrics import Precision, Recall

# %%
def train(data, EPOCHS):
    # Loop through epochs
    for epoch in range(1, EPOCHS+1):
        print('\n Epoch {}/{}'.format(epoch, EPOCHS))
        progbar = tf.keras.utils.Progbar(len(data))
        
        # Creating a metric object 
        r = Recall()
        p = Precision()
        
        # Loop through each batch
        for idx, batch in enumerate(data):
            # Run train step here
            loss = train_step(batch)
            yhat = siamese_model.predict(batch[:2])
            r.update_state(batch[2], yhat)
            p.update_state(batch[2], yhat) 
            progbar.update(idx+1)
        print(loss.numpy(), r.result().numpy(), p.result().numpy())
        
        # Save checkpoints
        if epoch % 10 == 0: 
            checkpoint.save(file_prefix=checkpoint_prefix)

# %% [markdown]
# # 5.5 Train the model

# %%
EPOCHS = 50

# %%
train(train_data, EPOCHS)
# Out:
#  Epoch 1/50
# Tensor("binary_crossentropy/weighted_loss/value:0", shape=(), dtype=float32)
# Tensor("binary_crossentropy/weighted_loss/value:0", shape=(), dtype=float32)
# 10/11 [==========================>...] - ETA: 52s Tensor("binary_crossentropy/weighted_loss/value:0", shape=(), dtype=float32)
# 11/11 [==============================] - 554s 47s/step
# 0.36763597 0.36486486 1.0
#
#  Epoch 2/50
# 11/11 [==============================] - 239s 22s/step
# 0.5451441 0.8 1.0
#
#  Epoch 3/50
# 11/11 [==============================] - 447s 42s/step
# 0.008102447 0.97619045 1.0
#
#  Epoch 4/50
# 11/11 [==============================] - 214s 19s/step
# 0.43629953 1.0 1.0
#
#  Epoch 5/50
# 11/11 [==============================] - 213s 19s/step
# 0.018349621 1.0 1.0
#
#  Epoch 6/50
# 11/11 [==============================] - 1349s 133s/step
# 0.01423888 1.0 1.0
#
#  Epoch 7/50
# 11/11 [==============================] - 224s 20s/step
# 0.00057295 1.0 1.0
#
#  Epoch 8/50
# 11/11 [==============================] - 223s 20s/step
# 0.069967516 1.0 1.0
#
#  Epoch 9/50
# 11/11 [==============================] - 225s 20s/step
# 0.024132516 1.0 1.0
#
#  Epoch 10/50
# 11/11 [==============================] - 226s 20s/step
# 0.0 0.9868421 1.0
#
#  Epoch 11/50
# 11/11 [==============================] - 226s 20s/step
# 0.002571838 0.9875 0.97530866
#
#  Epoch 12/50
# 11/11 [==============================] - 226s 20s/step
# 0.0006824829 1.0 1.0
#
#  Epoch 13/50
# 11/11 [==============================] - 228s 20s/step
# 0.0026368168 0.974359 1.0
#
#  Epoch 14/50
# 11/11 [==============================] - 226s 20s/step
# 0.00838679 1.0 0.9864865
#
#  Epoch 15/50
# 11/11 [==============================] - 227s 20s/step
# 0.010066008 1.0 1.0
#
#  Epoch 16/50
# 11/11 [==============================] - 220s 20s/step
# 0.00063739234 1.0 1.0
#
#  Epoch 17/50
# 11/11 [==============================] - 221s 20s/step
# 0.00019885083 1.0 1.0
#
#  Epoch 18/50
# 11/11 [==============================] - 217s 20s/step
# 6.2287204e-06 1.0 1.0
#
#  Epoch 19/50
# 11/11 [==============================] - 236s 21s/step
# 1.1324889e-06 1.0 1.0
#
#  Epoch 20/50
# 11/11 [==============================] - 280s 20s/step
# 5.960468e-07 1.0 1.0
#
#  Epoch 21/50
# 11/11 [==============================] - 227s 20s/step
# 1.7881396e-07 1.0 1.0
#
#  Epoch 22/50
# 11/11 [==============================] - 231s 21s/step
# 2.980233e-07 1.0 1.0
#
#  Epoch 23/50
# 11/11 [==============================] - 230s 21s/step
# 6.2584917e-07 1.0 1.0
#
#  Epoch 24/50
# 11/11 [==============================] - 230s 21s/step
# 1.4901163e-07 1.0 1.0
#
#  Epoch 25/50
# 11/11 [==============================] - 227s 20s/step
# 9.149396e-06 1.0 1.0
#
#  Epoch 26/50
# 11/11 [==============================] - 228s 20s/step
# 0.0020958087 1.0 1.0
#
#  Epoch 27/50
# 11/11 [==============================] - 229s 21s/step
# 2.980233e-07 1.0 1.0
#
#  Epoch 28/50
# 11/11 [==============================] - 227s 20s/step
# 0.0 1.0 1.0
#
#  Epoch 29/50
# 11/11 [==============================] - 227s 20s/step
# 3.3974732e-06 1.0 1.0
#
#  Epoch 30/50
# 11/11 [==============================] - 228s 21s/step
# 0.0058507966 1.0 1.0
#
#  Epoch 31/50
# 11/11 [==============================] - 232s 21s/step
# 0.0004367351 1.0 1.0
#
#  Epoch 32/50
# 11/11 [==============================] - 231s 21s/step
# 9.573423e-05 1.0 1.0
#
#  Epoch 33/50
# 11/11 [==============================] - 232s 21s/step
# 4.142532e-06 1.0 1.0
#
#  Epoch 34/50
# 11/11 [==============================] - 234s 21s/step
# 8.9407047e-07 1.0 1.0
#
#  Epoch 35/50
# 11/11 [==============================] - 235s 21s/step
# 2.980233e-07 1.0 1.0
#
#  Epoch 36/50
# 11/11 [==============================] - 230s 21s/step
# 0.0 1.0 1.0
#
#  Epoch 37/50
# 11/11 [==============================] - 229s 21s/step
# 1.7881395e-07 1.0 1.0
#
#  Epoch 38/50
# 11/11 [==============================] - 235s 21s/step
# 9.1792e-06 1.0 1.0
#
#  Epoch 39/50
# 11/11 [==============================] - 231s 21s/step
# 0.0 1.0 1.0
#
#  Epoch 40/50
# 11/11 [==============================] - 228s 21s/step
# 3.5166856e-06 1.0 1.0
#
#  Epoch 41/50
# 11/11 [==============================] - 228s 21s/step
# 6.18138e-05 1.0 1.0
#
#  Epoch 42/50
# 11/11 [==============================] - 229s 21s/step
# 1.7881396e-07 1.0 1.0
#
#  Epoch 43/50
# 11/11 [==============================] - 231s 21s/step
# 5.7220786e-06 1.0 1.0
#
#  Epoch 44/50
# 11/11 [==============================] - 230s 21s/step
# 3.096552e-05 1.0 1.0
#
#  Epoch 45/50
# 11/11 [==============================] - 228s 21s/step
# 3.4393048e-05 1.0 1.0
#
#  Epoch 46/50
# 11/11 [==============================] - 228s 21s/step
# 1.4901164e-07 1.0 1.0
#
#  Epoch 47/50
# 11/11 [==============================] - 231s 21s/step
# 7.7486084e-07 1.0 1.0
#
#  Epoch 48/50
# 11/11 [==============================] - 231s 21s/step
# 1.2218967e-06 1.0 1.0
#
#  Epoch 49/50
# 11/11 [==============================] - 232s 21s/step
# 0.00033025918 1.0 1.0
#
#  Epoch 50/50
# 11/11 [==============================] - 229s 21s/step
# 3.1948857e-05 1.0 1.0

# %% [markdown]
# # 6. Evaluate Model

# %% [markdown]
# # 6.1 Import Metrics

# %%
# Import metric calculations
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# # 6.2 Make Predictions

# %%
# Get a batch of test data
test_input, test_val, y_true = test_data.as_numpy_iterator()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [77], in <cell line: 2>()
#       1 # Get a batch of test data
# ----> 2 test_input, test_val, y_true = test_data.as_numpy_iterator()
#
# ValueError: too many values to unpack (expected 3)

# %%
y_hat = siamese_model.predict([test_input, test_val])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
# ----> 1 y_hat = siamese_model.predict([test_input, test_val])
#
# NameError: name 'test_input' is not defined

# %%
# Post processing the results 
[1 if prediction > 0.5 else 0 for prediction in y_hat ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [79], in <cell line: 2>()
#       1 # Post processing the results
# ----> 2 [1 if prediction > 0.5 else 0 for prediction in y_hat ]
#
# NameError: name 'y_hat' is not defined

# %%
y_true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 y_true
#
# NameError: name 'y_true' is not defined

# %% [markdown]
# # 6.3 Calculate Metrics

# %%
# Creating a metric object 
m = Recall()

# Calculating the recall value 
m.update_state(y_true, y_hat)

# Return Recall Result
m.result().numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 5>()
#       2 m = Recall()
#       4 # Calculating the recall value
# ----> 5 m.update_state(y_true, y_hat)
#       7 # Return Recall Result
#       8 m.result().numpy()
#
# NameError: name 'y_true' is not defined

# %%
# Creating a metric object 
m = Precision()

# Calculating the recall value 
m.update_state(y_true, y_hat)

# Return Recall Result
m.result().numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [82], in <cell line: 5>()
#       2 m = Precision()
#       4 # Calculating the recall value
# ----> 5 m.update_state(y_true, y_hat)
#       7 # Return Recall Result
#       8 m.result().numpy()
#
# NameError: name 'y_true' is not defined

# %%
r = Recall()
p = Precision()

for test_input, test_val, y_true in test_data.as_numpy_iterator():
    yhat = siamese_model.predict([test_input, test_val])
    r.update_state(y_true, yhat)
    p.update_state(y_true,yhat) 

print(r.result().numpy(), p.result().numpy())
# Out:
# 1.0 1.0

# %% [markdown]
# # 6.4 Viz Results

# %%
# Set plot size 
plt.figure(figsize=(10,8))

# Set first subplot
plt.subplot(1,2,1)
plt.imshow(test_input[0])

# Set second subplot
plt.subplot(1,2,2)
plt.imshow(test_val[0])

# Renders cleanly
plt.show()

# %% [markdown]
# # 7. Save Model

# %%
# Save weights
siamese_model.save('siamesemodel.h5')

# %%
L1Dist
# Out:
# __main__.L1Dist

# %%
# Reload model 
siamese_model = tf.keras.models.load_model('siamesemodel.h5', 
                                   custom_objects={'L1Dist':L1Dist, 'BinaryCrossentropy':tf.losses.BinaryCrossentropy})
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# Make predictions with reloaded model
siamese_model.predict([test_input, test_val])
# Out:
# array([[2.3605972e-07],
#        [1.3458932e-08],
#        [9.9999821e-01],
#        [3.4942073e-07],
#        [1.0000000e+00]], dtype=float32)

# %%
# View model summary
siamese_model.summary()
# Out:
# Model: "SiameseNetwork"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_img (InputLayer)          [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# validation_img (InputLayer)     [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# embedding (Functional)          (None, 4096)         38960448    input_img[0][0]
#                                                                  validation_img[0][0]
# __________________________________________________________________________________________________
# l1_dist_3 (L1Dist)              (None, 4096)         0           embedding[0][0]
#                                                                  embedding[1][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            4097        l1_dist_3[0][0]
# ==================================================================================================
# Total params: 38,964,545
# Trainable params: 38,964,545
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 8. Real Time Test

# %% [markdown]
# # 8.1 Verification Function

# %%
application_data\verification_images
# Out:
#   Input In [90]
#     application_data\verification_images
#                                         ^
# SyntaxError: unexpected character after line continuation character

# %%
os.listdir(os.path.join('application_data', 'verification_images'))
# Out:
# ['46b51309-d87e-11ec-b498-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  '46c35685-d87e-11ec-86b9-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  '46df696f-d87e-11ec-a3d7-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  '4744a862-d87e-11ec-aa79-38fc98e17070 - Copy - Copy - Copy.jpg',
#  '47a76e0e-d87e-11ec-9ca4-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  '47bf2ee9-d87e-11ec-913f-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  '47f57423-d87e-11ec-810d-38fc98e17070 - Copy - Copy - Copy.jpg',
#  '485aed6e-d87e-11ec-9f2f-38fc98e17070 - Copy - Copy - Copy.jpg',
#  '48a46e20-d87e-11ec-b2ae-38fc98e17070 - Copy - Copy - Copy.jpg',
#  '491acf4d-d87e-11ec-aad7-38fc98e17070 - Copy - Copy - Copy.jpg',
#  '4940e21b-d87e-11ec-833f-38fc98e17070 - Copy - Copy - Copy.jpg',
#  '4968b520-d87e-11ec-8703-38fc98e17070 - Copy - Copy - Copy.jpg',
#  '4976e5c3-d87e-11ec-921c-38fc98e17070 - Copy - Copy - Copy.jpg',
#  '49b6e5f8-d87e-11ec-b629-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  '49e8d295-d87e-11ec-b1df-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  '4ad70e6d-d87e-11ec-8dc3-38fc98e17070 - Copy - Copy - Copy - Copy - Copy.jpg',
#  '4afc746b-d87e-11ec-8f0c-38fc98e17070 - Copy - Copy - Copy - Copy - Copy.jpg',
#  '4b8a76fe-d87e-11ec-91c0-38fc98e17070 - Copy - Copy - Copy - Copy - Copy.jpg',
#  '4bc5ab98-d87e-11ec-9770-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  '4bd375ca-d87e-11ec-b075-38fc98e17070 - Copy (2) - Copy - Copy - Copy.jpg',
#  '4bd375ca-d87e-11ec-b075-38fc98e17070 - Copy - Copy - Copy - Copy - Copy.jpg',
#  '4be1c729-d87e-11ec-8de5-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  '4bf047cd-d87e-11ec-98e2-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  '4c05b24e-d87e-11ec-bb3f-38fc98e17070 - Copy - Copy - Copy - Copy.jpg',
#  'bfa6d122-d792-11ec-945d-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'c064acac-d792-11ec-94de-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'c0e82903-d792-11ec-80d7-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'c16c2720-d792-11ec-8960-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'c21b9fa2-d792-11ec-9a20-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'c24a25cc-d792-11ec-a86d-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'c2d1e2e0-d792-11ec-92b3-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'd342ebe9-d86f-11ec-8305-38fc98e17070 - Copy.jpg',
#  'd374947d-d86f-11ec-ba75-38fc98e17070 - Copy.jpg',
#  'd52cb720-d86f-11ec-8626-38fc98e17070 - Copy (2) - Copy.jpg',
#  'd52cb720-d86f-11ec-8626-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'd547d7af-d86f-11ec-a0a9-38fc98e17070 - Copy.jpg',
#  'd54e1827-d86f-11ec-90d4-38fc98e17070 - Copy.jpg',
#  'd5638b9f-d86f-11ec-8fc6-38fc98e17070 - Copy.jpg',
#  'd5e41af2-d86f-11ec-9b59-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'd5f7511a-d86f-11ec-b4c1-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'd64892ee-d86f-11ec-a372-38fc98e17070 - Copy.jpg',
#  'd656c0dc-d86f-11ec-be27-38fc98e17070 - Copy.jpg',
#  'd6731736-d86f-11ec-b13c-38fc98e17070 - Copy.jpg',
#  'd6b83c5f-d86f-11ec-969a-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'd78ae976-d86f-11ec-88d0-38fc98e17070 - Copy.jpg',
#  'd78ae976-d86f-11ec-88d0-38fc98e17070.jpg',
#  'd79984d6-d86f-11ec-8b9d-38fc98e17070 - Copy.jpg',
#  'd7ea9a4f-d86f-11ec-ac73-38fc98e17070 - Copy - Copy - Copy.jpg',
#  'd82a2fe8-d86f-11ec-a489-38fc98e17070 - Copy.jpg',
#  'd89ca1ce-d86f-11ec-bc3d-38fc98e17070 - Copy.jpg']

# %%
os.path.join('application_data', 'input_image', 'input_image.jpg')
# Out:
# 'application_data\\input_image\\input_image.jpg'

# %%
os.path.join('application_data', 'input_image', 'input_image.jpg')
# Out:
# 'application_data\\input_image\\input_image.jpg'

# %%
for image in os.listdir(os.path.join('application_data', 'verification_images')):
    validation_img = os.path.join('application_data', 'verification_images', image)
    print(validation_img)
# Out:
# application_data\verification_images\46b51309-d87e-11ec-b498-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\46c35685-d87e-11ec-86b9-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\46df696f-d87e-11ec-a3d7-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\4744a862-d87e-11ec-aa79-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\47a76e0e-d87e-11ec-9ca4-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\47bf2ee9-d87e-11ec-913f-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\47f57423-d87e-11ec-810d-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\485aed6e-d87e-11ec-9f2f-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\48a46e20-d87e-11ec-b2ae-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\491acf4d-d87e-11ec-aad7-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\4940e21b-d87e-11ec-833f-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\4968b520-d87e-11ec-8703-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\4976e5c3-d87e-11ec-921c-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\49b6e5f8-d87e-11ec-b629-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\49e8d295-d87e-11ec-b1df-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\4ad70e6d-d87e-11ec-8dc3-38fc98e17070 - Copy - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\4afc746b-d87e-11ec-8f0c-38fc98e17070 - Copy - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\4b8a76fe-d87e-11ec-91c0-38fc98e17070 - Copy - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\4bc5ab98-d87e-11ec-9770-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\4bd375ca-d87e-11ec-b075-38fc98e17070 - Copy (2) - Copy - Copy - Copy.jpg
# application_data\verification_images\4bd375ca-d87e-11ec-b075-38fc98e17070 - Copy - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\4be1c729-d87e-11ec-8de5-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\4bf047cd-d87e-11ec-98e2-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\4c05b24e-d87e-11ec-bb3f-38fc98e17070 - Copy - Copy - Copy - Copy.jpg
# application_data\verification_images\bfa6d122-d792-11ec-945d-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\c064acac-d792-11ec-94de-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\c0e82903-d792-11ec-80d7-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\c16c2720-d792-11ec-8960-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\c21b9fa2-d792-11ec-9a20-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\c24a25cc-d792-11ec-a86d-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\c2d1e2e0-d792-11ec-92b3-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\d342ebe9-d86f-11ec-8305-38fc98e17070 - Copy.jpg
# application_data\verification_images\d374947d-d86f-11ec-ba75-38fc98e17070 - Copy.jpg
# application_data\verification_images\d52cb720-d86f-11ec-8626-38fc98e17070 - Copy (2) - Copy.jpg
# application_data\verification_images\d52cb720-d86f-11ec-8626-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\d547d7af-d86f-11ec-a0a9-38fc98e17070 - Copy.jpg
# application_data\verification_images\d54e1827-d86f-11ec-90d4-38fc98e17070 - Copy.jpg
# application_data\verification_images\d5638b9f-d86f-11ec-8fc6-38fc98e17070 - Copy.jpg
# application_data\verification_images\d5e41af2-d86f-11ec-9b59-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\d5f7511a-d86f-11ec-b4c1-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\d64892ee-d86f-11ec-a372-38fc98e17070 - Copy.jpg
# application_data\verification_images\d656c0dc-d86f-11ec-be27-38fc98e17070 - Copy.jpg
# application_data\verification_images\d6731736-d86f-11ec-b13c-38fc98e17070 - Copy.jpg
# application_data\verification_images\d6b83c5f-d86f-11ec-969a-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\d78ae976-d86f-11ec-88d0-38fc98e17070 - Copy.jpg
# application_data\verification_images\d78ae976-d86f-11ec-88d0-38fc98e17070.jpg
# application_data\verification_images\d79984d6-d86f-11ec-8b9d-38fc98e17070 - Copy.jpg
# application_data\verification_images\d7ea9a4f-d86f-11ec-ac73-38fc98e17070 - Copy - Copy - Copy.jpg
# application_data\verification_images\d82a2fe8-d86f-11ec-a489-38fc98e17070 - Copy.jpg
# application_data\verification_images\d89ca1ce-d86f-11ec-bc3d-38fc98e17070 - Copy.jpg

# %%
def verify(model, detection_threshold, verification_threshold):
    # Build results array
    results = []
    for image in os.listdir(os.path.join('application_data', 'verification_images')):
        input_img = preprocess(os.path.join('application_data', 'input_image', 'input_image.jpg'))
        validation_img = preprocess(os.path.join('application_data', 'verification_images', image))
        
        # Make Predictions 
        result = model.predict(list(np.expand_dims([input_img, validation_img], axis=1)))
        results.append(result)
    
    # Detection Threshold: Metric above which a prediciton is considered positive 
    detection = np.sum(np.array(results) > detection_threshold)
    
    # Verification Threshold: Proportion of positive predictions / total positive samples 
    verification = detection / len(os.listdir(os.path.join('application_data', 'verification_images'))) 
    verified = verification > verification_threshold
    
    return results, verified

# %% [markdown]
# # 8.2 OpenCV Real Time Verification

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    frame = frame[120:120+250,200:200+250, :]
    
    cv2.imshow('Verification', frame)
    
    # Verification trigger
    if cv2.waitKey(10) & 0xFF == ord('v'):
        # Save input image to application_data/input_image folder 
#         hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
#         h, s, v = cv2.split(hsv)q

#         lim = 255 - 10
#         v[v > lim] = 255
#         v[v <= lim] -= 10
        
#         final_hsv = cv2.merge((h, s, v))
#         img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)

        cv2.imwrite(os.path.join('application_data', 'input_image', 'input_image.jpg'), frame)
        # Run verification
        results, verified = verify(siamese_model, 0.9, 0.9)
        print(verified)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# True

# %%
np.sum(np.squeeze(results) > 0.9)
# Out:
# 48

# %%
img.numpy().max()
# Out:
# 0.98112744

# %%
img.numpy().max()
# Out:
# 0.98112744

# %%
results
# Out:
# [array([[0.9178779]], dtype=float32),
#  array([[0.9178779]], dtype=float32),
#  array([[0.916883]], dtype=float32),
#  array([[0.9189675]], dtype=float32),
#  array([[0.91868496]], dtype=float32),
#  array([[0.9182302]], dtype=float32),
#  array([[0.9173773]], dtype=float32),
#  array([[0.9186237]], dtype=float32),
#  array([[0.91910946]], dtype=float32),
#  array([[0.91925573]], dtype=float32),
#  array([[0.91829944]], dtype=float32),
#  array([[0.9159419]], dtype=float32),
#  array([[0.9158529]], dtype=float32),
#  array([[0.9176092]], dtype=float32),
#  array([[0.91831315]], dtype=float32),
#  array([[0.91871053]], dtype=float32),
#  array([[0.9104992]], dtype=float32),
#  array([[0.7878629]], dtype=float32),
#  array([[0.91890335]], dtype=float32),
#  array([[0.91890335]], dtype=float32),
#  array([[0.91890335]], dtype=float32),
#  array([[0.9189025]], dtype=float32),
#  array([[0.9186263]], dtype=float32),
#  array([[0.9185859]], dtype=float32),
#  array([[0.54315823]], dtype=float32),
#  array([[0.53966343]], dtype=float32),
#  array([[0.5492302]], dtype=float32),
#  array([[0.54849756]], dtype=float32),
#  array([[0.5488798]], dtype=float32),
#  array([[0.5488704]], dtype=float32),
#  array([[0.5416599]], dtype=float32),
#  array([[0.81981874]], dtype=float32),
#  array([[0.80044174]], dtype=float32),
#  array([[0.829792]], dtype=float32),
#  array([[0.829792]], dtype=float32),
#  array([[0.8500062]], dtype=float32),
#  array([[0.8500062]], dtype=float32),
#  array([[0.8426801]], dtype=float32),
#  array([[0.8289257]], dtype=float32),
#  array([[0.66601044]], dtype=float32),
#  array([[0.58468986]], dtype=float32),
#  array([[0.58290267]], dtype=float32),
#  array([[0.592652]], dtype=float32),
#  array([[0.8366973]], dtype=float32),
#  array([[0.7668536]], dtype=float32),
#  array([[0.7668536]], dtype=float32),
#  array([[0.6303262]], dtype=float32),
#  array([[0.68993294]], dtype=float32),
#  array([[0.82917666]], dtype=float32),
#  array([[0.7937063]], dtype=float32)]
